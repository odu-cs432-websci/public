# %% [markdown]
# <a href="https://colab.research.google.com/github/cs432-websci-fall20/assignments/blob/master/432_Week_02_lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 2 - CS 432/532 Fall 2020 - Python Lab

# %% [markdown]
# *The goal of this lab assignment is to give you experience writing Python code to accomplish common tasks, including using the requests and Beautiful Soup libraries. For each question below, add a Code segment with your solution.*
#
# *Save this notebook in your own Google Drive for later reference.*
#
# ***This is an optional assignment, but you are strongly encouraged to complete it.***
#
# *Post any questions in the 'q&a' section in Piazza. Feel free to answer your fellow classmates' questions.*

# %% [markdown]
# ## Basics

# %% [markdown]
# 1) Accept a number from the user and print whether the number is even or odd.

# %% [markdown]
# 2) Compute the number of lines and characters in a file.
#
# The text file is available at https://github.com/cs432-websci-fall20/assignments/blob/master/gettysburg.txt
#
# Download the "Raw" version and upload it to your Google Colab temporary file space.

# %% [markdown]
# ## Regular Expressions

# %% [markdown]
# 1) Using regex, extract the year, month, and day from a Wayback Machine style URI.
#
# Example: The date in http://web.archive.org/web/20190324134545/https://odu.edu/compsci/ is 2019-03-24
#
# Show that your code works with at least 3 other URIs. You can discover these at http://web.archive.org/

# %% [markdown]
# 2) Using regex, extract the hostname of the original URI (URI-R) from the 4 URIs used in Q1 above (or 4 others that have different URI-R hostnames).
#
# Example: The URI-R hostname of http://web.archive.org/web/20190324134545/https://odu.edu/compsci/ is odu.edu

# %% [markdown]
# ## Web Scraping

# %% [markdown]
# *Use the requests and/or Beautiful Soup libraries as needed.*

# %% [markdown]
# 1) Ask for a URI from the user. Request the URI and print the content type of the  returned representation.

# %% [markdown]
# 2) Download robots.txt for en.wikipedia.org and display the first 20 lines.

# %% [markdown]
# 3) Ask for a URI from the user. Use the requests library with `allow_redirects=False` and continually request URIs until they terminate (end in something other than 3xx). That is, if you receive a 3xx status, find the `Location:` header and make the request for that URI.

# %% [markdown]
# 4) List of all the h1, h2, h3 tags from the webpage https://python.org

# %% [markdown]
# 5) By examining the content of https://www.data.gov/, print out the current number of datasets available.
#
# (Here's a nice (detailed) description of how to examine a webpage's structure: https://www.dataquest.io/blog/web-scraping-beautifulsoup/)

# %% [markdown]
# 6) Write a version of Q1 that takes the URI as a command-line argument instead of from user input. Make sure that your program responds appropriately if there are no command-line arguments provided.
#
# *Test this code in a local version of Python and include the code here. Use a Text block and surround your code with*
#
# \```python
#
# *insert code here*
#
# ```
